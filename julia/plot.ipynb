# %% [markdown]
# ## 3-d plots in julia lorentz series

# %%
using Plots
Base.@kwdef mutable struct Lorenz
    dt::Float64 = 0.02
    σ::Float64 = 10
    ρ::Float64 = 28
    β::Float64 = 8/3
    x::Float64 = 1
    y::Float64 = 1
    z::Float64 = 1
end
# Out:
# Lorenz

# %%
function step!(l::Lorenz)
    dx = l.σ * (l.y - l.x);         l.x += l.dt * dx
    dy = l.x * (l.ρ - l.z) - l.y;   l.y += l.dt * dy
    dz = l.x * l.y - l.β * l.z;     l.z += l.dt * dz
end
# Out:
# step! (generic function with 1 method)

# %%
attractor = Lorenz()


# initialize a 3D plot with 1 empty series
plt = plot3d(
    1,
    xlim = (-30, 30),
    ylim = (-30, 30),
    zlim = (0, 60),
    title = "Lorenz Attractor",
    marker = 2,
)

# %%
@gif for i=1:1500
    step!(attractor)
    push!(plt, attractor.x, attractor.y, attractor.z)
end every 10
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\Abhishek Parashar\Desktop\tmp.gif
# └ @ Plots C:\Users\Abhishek Parashar\.juliapro\JuliaPro_v1.4.0-1\packages\Plots\8GUYs\src\animation.jl:102
# Plots.AnimatedGif("C:\\Users\\Abhishek Parashar\\Desktop\\tmp.gif")
